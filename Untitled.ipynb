# %% [markdown]
# # Describing Distributions

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
# Loading in data

df = pd.read_csv('Data/Medical_Dataset.csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
df['VitD_levels'].isna().sum()
# Out:
# 0

# %%
# getting mean/median/std for plotting
vitD_mean = df['VitD_levels'].mean()
vitD_median = df['VitD_levels'].median()
vitD_std = df['VitD_levels'].std()
vitD_std_plus = vitD_mean + vitD_std
vitD_std_minus = vitD_mean - vitD_std

# %%
# Plotting 
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x= df['VitD_levels'], kde='true', ax = ax);
ax.axvline(vitD_mean, color='red', label='mean');
ax.axvline(vitD_median, ls= '--', color='green', label='median');
ax.axvline(vitD_std_plus, color='black', label='+1 std');
ax.axvline(vitD_std_minus, color='black', label='-1 std');
ax.axvspan(vitD_std_plus, vitD_std_minus, color='yellow');
ax.legend();
ax.set_title('Distribution of Vitamin D levels')
# Out:
# Text(0.5, 1.0, 'Distribution of Vitamin D levels')

# %%
# Getting mean/median/std for Doc visits

doc_v_mean = df['Doc_visits'].mean()
doc_v_median = df['Doc_visits'].median()
doc_v_std = df['Doc_visits'].std()
doc_v_std_plus = doc_v_mean + doc_v_std
doc_v_std_minus = doc_v_mean - doc_v_std

# %%
# Plotting 
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x=df['Doc_visits'], kde='true', ax=ax);
ax.axvline(doc_v_mean, color='red', label='mean');
ax.axvline(doc_v_median, ls='--', color='green', label='median');
ax.axvline(doc_v_std_plus, color='black', label='+1 std');
ax.axvline(doc_v_std_minus, color='black', label='-1 std');
ax.axvspan(doc_v_std_plus, doc_v_std_minus, color='yellow');
ax.legend();
ax.set_title('Distribution of Doctors Visits');

# %%
# Getting mean/median/std of totalcharge

charge_mean = df['TotalCharge'].mean()
charge_median = df['TotalCharge'].median()
charge_std = df['TotalCharge'].std()
charge_std_plus = charge_mean + charge_std
charge_std_minus = charge_mean - charge_std

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x=df['TotalCharge'], kde='true', ax=ax);
ax.axvline(charge_mean, color='red', label='mean');
ax.axvline(charge_median, ls='--', color='green', label='median');
ax.axvline(charge_std_plus, color='black', label='+1 std');
ax.axvline(charge_std_minus, color='black', label='-1 std');
ax.axvspan(charge_std_plus, charge_std_minus, color='yellow');
ax.legend();
ax.set_title('Distribution of Total Charges');
